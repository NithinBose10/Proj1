# %%
import pandas as pd
pd.set_option('max_rows', 20)
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
import dash
from dash.dependencies import Input, Output
# import dash_core_components as dcc
from dash import dcc
# import dash_html_components as html
from dash import html
import dash_bootstrap_components as dbc

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

import plotly
import plotly.express as px
import plotly.graph_objects as go
#plt.rcParams['figure.figsize']=17,8
import cufflinks as cf
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

import folium

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
import datetime
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
df=pd.read_excel(r"C:\Users\bnith\Downloads\TN.xlsx", sheet_name='TN_case_info')

# %%
df
# Out:
#            date  testing_facilities  government_testing_facilities  \
# 0    2020-07-23                 113                             58
# 1    2020-07-24                 114                             58
# 2    2020-07-25                 115                             58
# 3    2020-07-26                 116                             58
# 4    2020-07-28                 119                             58
# ..          ...                 ...                            ...
# 508  2022-01-21                 326                             69
# 509  2022-01-22                 328                             69
# 510  2022-01-23                 330                             69
# 511  2022-01-24                 330                             69
# 512  2022-01-25                 331                             69
#
#      private_testing_facilities  active_cases_yesterday  \
# 0                            55                   51765
# ...

# %% [markdown]
# Total Positive Cases

# %%
df.iplot(kind='scatter',x='date',y='positive_tested_cases',mode='lines',title='My Graph',xTitle='Date',yTitle='Total Cases',colors='red',size=20)
# Out:
# <div>                            <div id="1348da02-e39d-4fc4-9024-ede7e82f4754" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Testing Facilities

# %%
df.iplot(kind='scatter',x='date',y='testing_facilities',mode='lines',title='My Graph',xTitle='Date',yTitle='Total Facilities',colors='red',size=20)
# Out:
# <div>                            <div id="0e096cd3-0c6d-4ba2-9e40-d4746c1a3b19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Daily Deaths

# %%
df.iplot(kind='scatter',x='date',y='deaths_today',mode='lines',title='Daily Deaths',xTitle='Date',yTitle='Daily Death',colors='black',size=2)
# Out:
# <div>                            <div id="16d93f42-b0a3-47c9-aa09-ea37137aacde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
dfp=pd.read_excel(r"C:\Users\bnith\Downloads\TN.xlsx", sheet_name='TN_positive_cases_detail')

# %%
dfp
# Out:
#            date  active_cases  tested_positive_today  \
# 0    2020-08-09         53336                   5974
# 1    2020-08-10         53099                   5879
# 2    2020-08-11         52810                   5814
# 3    2020-08-13         53499                   5810
# 4    2020-08-14         53716                   5862
# ..          ...           ...                    ...
# 492  2022-01-21        187358                  29848
# 493  2022-01-22        194697                  30718
# 494  2022-01-23        200954                  30567
# 495  2022-01-24        206484                  30208
# 496  2022-01-25        211270                  30039
#
#      tested_positive_till_date  rtpcr_samples_tested_today  \
# 0                       296901                       70186
# 1                       302815                       67153
# 2                       308649                       67492
# 3                       320355                       67275
# ...

# %% [markdown]
# Active Cases

# %%
dfp.iplot(kind='scatter',x='date',y='active_cases',mode='lines',title='Active Cases',xTitle='Date',yTitle='Active Cases',colors='blue',size=2)
# Out:
# <div>                            <div id="4186a26b-7ffc-47ec-81b4-c0e9db601f59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# District Details

# %%
dfd=pd.read_excel(r"C:\Users\bnith\Downloads\TN.xlsx", sheet_name='TN_district_details')

# %%
dfd
# Out:
#              date                              district  \
# 0      2020-07-23       airport surveillance (domestic)
# 1      2020-07-23  airport surveillance (international)
# 2      2020-07-23                              ariyalur
# 3      2020-07-23                          chengalpattu
# 4      2020-07-23                               chennai
# ...           ...                                   ...
# 21228  2022-01-25                              tiruppur
# 21229  2022-01-25                                trichy
# 21230  2022-01-25                               vellore
# 21231  2022-01-25                            villupuram
# 21232  2022-01-25                          virudhunagar
#
#        total_active_cases_till_yesterday  new_cases_today  \
# 0                                     97                7
# 1                                    307                9
# 2                                    134               48
# ...

# %%
dt = dfd.groupby(['date', 'district'])

# %%
dt.first()
# Out:
#                                                  total_active_cases_till_yesterday  \
# date       district
# 2020-07-23 airport surveillance (domestic)                                      97
#            airport surveillance (international)                                307
#            ariyalur                                                            134
#            chengalpattu                                                       2542
#            chennai                                                           13947
# ...                                                                            ...
# 2022-01-25 tiruppur                                                           7309
#            trichy                                                             4718
#            vellore                                                            1845
#            villupuram                                                         2645
# ...

# %%
dt.sum()

# %%
dfd[dfd['district']=='erode'].groupby('total_deaths')

# %% [markdown]
# Total Deaths

# %%
ctb = dfd.pivot_table('total_deaths', 'district', 'date')

# %%
ctb.to_csv('total deaths')

# %%
ctb['2022-01-01']['erode']
# Out:
# 711.0

# %%
ctb['mayiladuthurai'].fillna(value=0.0, inplace=True)

# %%
ctb[ctb['mayiladuthurai'].notna()]

# %%
dfd.groupby('district')

# %%
int(ctb['erode'][-1])

# %%
d = input('Enter the district: ').lower()

# %%
int(ctb[d]['2020-10-25'])

# %%
dfd[dfd['district'] == 'erode']

# %% [markdown]
# Traverse through dates

# %%
start_date = datetime.date(2020, 1, 1)
end_date = datetime.date(2020, 1, 4)
delta = datetime.timedelta(days=1)

while start_date <= end_date:
    print(start_date)
    start_date += delta

# %%
ctb.loc()

# %%
df

# %%
df['positive_tested_cases']

# %%
df.iplot(kind='scatter', x='date',y='positive_tested_cases')
